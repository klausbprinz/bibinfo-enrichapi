# %% [markdown]
# ### test lobid models

# %%
import sys
import os
import json

# Fix Python path for notebook context
sys.path.insert(0, os.path.abspath(".."))

from src.enrichapi.models.lobidGND import DataLobidGND

# Simulated JSON payload from https://lobid.org/gnd/118610465.json
sample_data = {
    "type": ["Person", "AuthorityRecord"],
    "preferredName": "Schubert, Franz",
    "biographicalOrHistoricalInformation": ["Österr. Komponist"],
    "depiction": [
        {"id": "https://commons.wikimedia.org/wiki/Special:FilePath/Franz_Schubert.jpg"}
    ],
    "professionOrOccupation": [{"id": "https://...", "label": "Komponist"}],
    "dateOfBirth": ["1797-01-31"],
    "dateOfDeath": ["1828-11-19"],
    "geographicAreaCode": [
        {"id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT", "label": "Österreich"}
    ]
}

# Validate directly into DataLobidGND
result = DataLobidGND(gndId="118610465", gndInformation=sample_data)

print(f"Parsed Model Type: {type(result.gndInformation).__name__}")
print(f"Name: {result.gndInformation.preferredName}")
print(f"Professions: {result.gndInformation.professionsOrOccupations}")
print(f"Depictions: {result.gndInformation.depictionURLs}")

# Test the geographic area code extraction
if result.gndInformation.geographicAreaCodes:
    geo = result.gndInformation.geographicAreaCodes[0]
    print(f"Geo Code: {geo.code}")      # XA-AT
    print(f"Geo URL: {geo.idURL}")      # https://d-nb.info/...#XA-AT
# Out:
# Parsed Model Type: PersonLobidGND
# Name: Schubert, Franz
# Professions: ['Komponist']
# Depictions: ['https://commons.wikimedia.org/wiki/Special:FilePath/Franz_Schubert.jpg']
# Geo Code: XA-AT
# Geo URL: https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT

# %% [markdown]
# ### new tests

# %% [markdown]
# #### Full Deep Extraction (SRU + Lobid + Wikidata Lookup) mit maxRecs implemented

# %%
import requests

url = "http://127.0.0.1:8000/enrich"

payload = {
    "iType": "bib",
    "institution": {
        "iName": "oenb",
        "isbn": "9780451524935",
        "fetchMarc21MD": False,
        "fetchLobidGND": False,
        "fetchWikidata": False,
        "fetchCover": True,        # <--- Explicitly request Cover
        "fetchDescription": True   # <--- Explicitly request Description
    }
}

res = requests.post(url, json=payload)
res.raise_for_status()

res.json()
# Out:
# {'response': {'iType': 'bib',
#   'result': {'identifier': None,
#    'basicMarc21MD': None,
#    'additionalRecsSRU': None,
#    'gndInfoLobid': None,
#    'wikidataData': None,
#    'bookCover': {'imageSize': 'M',
#     'isbn': '9780451524935',
#     'coverURL': 'https://covers.openlibrary.org/b/isbn/9780451524935-M.jpg?default=false'},
#    'bookDescription': {'description': "Nineteen Eighty-Four: A Novel, often referred to as 1984, is a dystopian social science fiction novel by the English novelist George Orwell (the pen name of Eric Arthur Blair). It was published on 8 June 1949 by Secker & Warburg as Orwell's ninth and final book completed in his lifetime. Thematically, Nineteen Eighty-Four centres on the consequences of totalitarianism, mass surveillance, and repressive regimentation of persons and behaviours within society. Orwell, himself a democratic socialist, modelled the authoritarian government in the novel after Stalinist Russia. More broadly, the novel examines the role of truth and facts within politics and the ways in which they are manipulated.\r\n\r\n----------\t\t\r\nAlso contained in:\t\t\r\n[Novels (Animal Farm / Burmese Days / Clergyman's Daughter / Coming Up for Air / Keep the Aspidistra Flying / Nineteen Eighty-Four)](https://openlibrary.org/works/OL1168045W)\t\t\r\n[Novels (Animal Farm / Nineteen Eighty-Four)](https://openlibrary.org/works/OL1167981W)\r\n[Orwell's Nineteen Eighty-Four: Text, Sources, Criticism](https://openlibrary.org/works/OL1168095W)"},
#    'iName': 'oenb',
#    'identifierType': None}}}

# %%
# with Volltext-URL: AC17288271
# with abstract: AC03987726
# with inhaltsverzeichnis: AC07527091
# Journal/Newspaper: AC02908223
# Kant: +Z168276302
# Safranski Schopenhauer: AC01514953

import requests

url = "http://127.0.0.1:8000/enrich"

payload = {
    "iType": "bib",
    "institution": {
        "iName": "oenb",
        "identifier": "AC07527091",
        "identifierType": "ac",
        "fetchMarc21MD": True,
        "fetchLobidGND": True,
        "fetchWikidata": True,
        "fetchSimilarByAuthor": True,
        "fetchSimilarBySubject": True,
        "fetchSimilarByClassification": True,
        "maxRecs": 10
    }
}

res = requests.post(url, json=payload)
res.raise_for_status()

res.json()
# Out:
# {'response': {'iType': 'bib',
#   'result': {'identifier': 'AC07527091',
#    'basicMarc21MD': {'title': {'titleMain': '100 Jahre Technisches Museum Wien',
#      'titleRemainder': None,
#      'titlePartNumber': [],
#      'titlePartName': []},
#     'mainEntry': None,
#     'addedEntries': [{'name': 'Lackner, Helmut',
#       'nameType': 'person',
#       'relator': ['edt'],
#       'gndIdentifier': '138881138'},
#      {'name': 'Technisches Museum Wien',
#       'nameType': 'corporate',
#       'relator': ['ctb'],
#       'gndIdentifier': '5344302-0'}],
#     'languageCodes': ['ger'],
#     'languageCodesOriginal': [],
#     'publicationCountryCodes': ['XA-AT'],
#     'edition': None,
#     'physicalDescriptions': [{'extent': '448 S.',
#       'otherPhysDetails': 'zahlr. Ill., graph. Darst., Kt.',
#       'dimensions': '30 cm'}],
#     'publicationNotices': [{'pnType': 'other',
#       'dating': None,
#       'places': ['Wien'],
#       'names': ['Ueberreuter'],
#       'dates': ['2009']}],
#     'genreForms': [],
#     'subjectHeadings': ['Technisches Museum Wien', 'Geschichte'],
#     'classifications': [{'classificationType': 'ddc',
#       'classificationNumber': '607.443613'},
#      {'classificationType': 'sdnb', 'classificationNumber': '060'},
#      {'classificationType': 'bkl', 'classificationNumber': '50.01'},
#      {'classificationType': 'rvk', 'classificationNumber': 'ZG 8200'},
#      {'classificationType': 'rvk', 'classificationNumber': 'ZG 8930'}],
#     'bibMaterialType': 'Book (BK)',
#     'bibResourceType': 'Book - Physical',
#     'fullTextURLs': [],
#     'abstracts': [],
#     'tableOfContentURLs': ['http://www.unileoben.ac.at/images/stories/Bibliothek/edoc/AC07527091n01in.pdf'],
#     'identifier': [{'value': '990016079320603338',
#       'idType': 'almaBib',
#       'prefix': None,
#       'additionalInfos': []},
#      {'value': 'AC07527091',
#       'idType': 'primaryBib',
#       'prefix': None,
#       'additionalInfos': []},
#      {'value': '9783800074198',
#       'idType': 'isbn',
#       'prefix': None,
#       'additionalInfos': []},
#      {'value': '9783800074198',
#       'idType': 'other',
#       'prefix': None,
#       'additionalInfos': []},
#      {'value': 'AC07527091',
#       'idType': 'systemId',
#       'prefix': '(AT-OBV)',
#       'additionalInfos': []},
#      {'value': 'AC07527091',
#       'idType': 'systemId',
#       'prefix': None,
#       'additionalInfos': []},
#      {'value': '007302383ACC01',
#       'idType': 'systemId',
#       'prefix': '(Aleph)',
#       'additionalInfos': []},
#      {'value': 'DNB991842758',
#       'idType': 'systemId',
#       'prefix': '(DE-599)',
#       'additionalInfos': []},
#      {'value': '990073023830203331',
#       'idType': 'systemId',
#       'prefix': '(EXLNZ-43ACC_NETWORK)',
#       'additionalInfos': []}],
#     'holdingInfos': [{'libraryCode': 'ZNEU',
#       'libraryLabel': 'Central Service Facility at Heldenplatz (NEU)',
#       'locationCode': 'MAG',
#       'locationLabel': 'Main Stacks at Heldenplatz (MAG)',
#       'callNumber': '1894200-C',
#       'itemInfos': {'numOfItems': 1, 'availability': 'available'}},
#      {'libraryCode': 'ZNEU',
#       'libraryLabel': 'Central Service Facility at Heldenplatz (NEU)',
#       'locationCode': 'MAG',
#       'locationLabel': 'Main Stacks at Heldenplatz (MAG)',
#       'callNumber': '1894198-C',
#       'itemInfos': {'numOfItems': 1, 'availability': 'available'}},
#      {'libraryCode': 'ZPOR',
#       'libraryLabel': 'Picture Archives and Graphics Department (POR)',
#       'locationCode': 'MAG',
#       'locationLabel': 'Picture Archives and Graphics Department (POR-MAG)',
#       'callNumber': '1896734-C',
#       'itemInfos': {'numOfItems': 1, 'availability': 'available'}}]},
#    'additionalRecsSRU': {'records': [{'searchType': 'author',
#       'name': '',
#       'maxRecs': 10,
#       'additionalRecs': []},
#      {'searchType': 'subjectHeadings',
#       'subjectHeadings': ['Technisches Museum Wien', 'Geschichte'],
#       'maxRecs': 10,
#       'additionalRecs': [{'ac': 'AC15510427',
#         'titleMain': '310.23 - eine österreichische Lokomotivlegende',
#         'callNumbers': ['2156292-C', '2156293-C'],
#         'isbns': ['9783903015142'],
#         'issns': []},
#        {'ac': 'AC15224253',
#         'titleMain': '90 Jahre Stereoskopie in Österreich',
#         'callNumbers': ['2153771-C', '2170487-C', '2153773-C'],
#         'isbns': [],
#         'issns': []},
#        {'ac': 'AC00288884',
#         'titleMain': 'Biedermeier-Steingläser',
#         'callNumbers': ['1346092-C'],
#         'isbns': [],
#         'issns': []},
#        {'ac': 'AC01823921',
#         'titleMain': 'Blühender Jugendstil - Österreich',
#         'callNumbers': ['1484755-B.2'],
#         'isbns': ['3900282196'],
#         'issns': []},
#        {'ac': 'AC08289266',
#         'titleMain': 'Echo unserer Zeit',
#         'callNumbers': ['1938136-B'],
#         'isbns': ['9783869555126'],
#         'issns': []},
#        {'ac': 'AC00236842',
#         'titleMain': 'Elektrostatik im Experiment',
#         'callNumbers': ['1216083-B'],
#         'isbns': [],
#         'issns': []},
#        {'ac': 'AC03330919',
#         'titleMain': 'Fahrräder - Motorräder - Automobile',
#         'callNumbers': ['1637306-C'],
#         'isbns': ['3902183020'],
#         'issns': []},
#        {'ac': 'AC00746127',
#         'titleMain': 'Farbenglas',
#         'callNumbers': [],
#         'isbns': [],
#         'issns': []},
#        {'ac': 'AC04711118',
#         'titleMain': 'Festschrift 50 Jahre Technisches Museum für Industrie und Gewerbe in Wien',
#         'callNumbers': ['1019923-C'],
#         'isbns': [],
#         'issns': []},
#        {'ac': 'AC03575670',
#         'titleMain': 'Forum',
#         'callNumbers': ['1672449-C'],
#         'isbns': [],
#         'issns': []}]},
#      {'searchType': 'classification',
#       'classifications': [{'classificationType': 'ddc',
#         'classificationNumber': '607.443613'},
#        {'classificationType': 'sdnb', 'classificationNumber': '060'},
#        {'classificationType': 'bkl', 'classificationNumber': '50.01'},
#        {'classificationType': 'rvk', 'classificationNumber': 'ZG 8200'},
#        {'classificationType': 'rvk', 'classificationNumber': 'ZG 8930'}],
#       'maxRecs': 10,
#       'additionalRecs': [{'ac': 'AC07812323',
#         'titleMain': '"... zur Aufmunterung der Landescultur"',
#         'callNumbers': ['1969615-C'],
#         'isbns': [],
#         'issns': []},
#        {'ac': 'AC03220951',
#         'titleMain': '<<Die>> "hochfürstliche Christallmühle" zu Salzburg',
#         'callNumbers': ['1626719-C'],
#         'isbns': [],
#         'issns': []},
#        {'ac': 'AC02969838',
#         'titleMain': '"Nützliche Künste"',
#         'callNumbers': ['1590497-B',
#          '1,553.757-B.Neu-',
#          '1,483.086-B.Neu-Per'],
#         'isbns': ['3893258175'],
#         'issns': []},
#        {'ac': 'AC15291763',
#         'titleMain': '<<Die>> 100 genialsten Erfindungen',
#         'callNumbers': ['2134915-C'],
#         'isbns': [],
#         'issns': []},
#        {'ac': 'AC15543597',
#         'titleMain': '100 great scientists who changed the world',
#         'callNumbers': ['2158215-C'],
#         'isbns': ['9781789503425'],
#         'issns': []},
#        {'ac': 'AC08127067',
#         'titleMain': '100 große Sprünge',
#         'callNumbers': ['1937255-B'],
#         'isbns': ['9783827424884'],
#         'issns': []},
#        {'ac': 'AC16695224',
#         'titleMain': '100 Jahre Erfindungen und Entdeckungen aus Niederösterreich',
#         'callNumbers': ['2220254-C'],
#         'isbns': [],
#         'issns': []},
#        {'ac': 'AC07675856',
#         'titleMain': '<<Die>> 100 wichtigsten Erfindungen',
#         'callNumbers': ['1904563-C'],
#         'isbns': ['9783570198841'],
#         'issns': []},
#        {'ac': 'AC15274134',
#         'titleMain': '1001 Erfindungen, die unsere Welt veränderten',
#         'callNumbers': ['2131744-B'],
#         'isbns': ['9783283012540', '3283012547'],
#         'issns': []},
#        {'ac': 'AC04427389',
#         'titleMain': '<<Die>> 101 wichtigsten Erfindungen der Weltgeschichte',
#         'callNumbers': ['1778087-B'],
#         'isbns': ['3406508596'],
#         'issns': []}]}]},
#    'gndInfoLobid': None,
#    'wikidataData': None,
#    'bookCover': None,
#    'bookDescription': None,
#    'iName': 'oenb',
#    'identifierType': 'ac'}}}

# %%
import requests

url = "http://127.0.0.1:8000/enrich"

payload = {
    "iType": "bib",
    "institution": {
        "iName": "oenb",
        "identifier": "AC08958802",
        "identifierType": "ac",
        "fetchMarc21MD": True,
        "fetchSimilarByAuthor": True,
        "maxRecs": 10
    }
}

res = requests.post(url, json=payload)
res.raise_for_status()

res.json()
# Out:
# {'response': {'iType': 'bib',
#   'result': {'identifier': 'AC08958802',
#    'basicMarc21MD': {'title': {'titleMain': 'Gold',
#      'titleRemainder': '[Gold in der Kunst, von der Antike bis zur Moderne ; dieser Katalog erscheint anlässlich der Ausstellung ... vom 15. März bis 17. Juni 2012 im Belvedere, Wien]',
#      'titlePartNumber': [],
#      'titlePartName': []},
#     'mainEntry': None,
#     'addedEntries': [{'name': 'Husslein-Arco, Agnes',
#       'nameType': 'personal',
#       'relator': ['edt'],
#       'gndIdentifier': '13045978X'},
#      {'name': 'Zaunschirm, Thomas',
#       'nameType': 'personal',
#       'relator': ['edt'],
#       'gndIdentifier': '120560631'},
#      {'name': 'Österreichische Galerie Belvedere',
#       'nameType': 'corporate',
#       'relator': ['ctb'],
#       'gndIdentifier': '2165327-6'}],
#     'languageCodes': ['ger'],
#     'languageCodesOriginal': [],
#     'publicationCountryCodes': ['XA-AT', 'XA-DE'],
#     'edition': None,
#     'physicalDescriptions': [{'extent': '367 S.',
#       'otherPhysDetails': 'zahlr. Ill., Kt.',
#       'dimensions': '33 cm'}],
#     'publicationNotices': [{'pnType': 'other',
#       'dating': None,
#       'places': ['Wien'],
#       'names': ['Belvedere'],
#       'dates': ['2012']},
#      {'pnType': 'other',
#       'dating': None,
#       'places': ['München'],
#       'names': ['Hirmer'],
#       'dates': ['2012']}],
#     'genreForms': ['Ausstellungskatalog'],
#     'subjectHeadings': ['Gold',
#      'Kunst',
#      'Kultur',
#      'Geschichte',
#      'Ausstellungskatalog',
#      'Wien <2012>',
#      'Künstlerisches Material'],
#     'classifications': [{'classificationType': 'ddc',
#       'classificationNumber': '702.807443613'},
#      {'classificationType': 'sdnb', 'classificationNumber': '700'},
#      {'classificationType': 'bkl', 'classificationNumber': '21.92'},
#      {'classificationType': 'bkl', 'classificationNumber': '15.07'},
#      {'classificationType': 'rvk', 'classificationNumber': 'LH 49600'},
#      {'classificationType': 'rvk', 'classificationNumber': 'LH 65020'},
#      {'classificationType': 'rvk', 'classificationNumber': 'LH 78490'}],
#     'bibMaterialType': 'Book (BK)',
#     'bibResourceType': 'Book - Physical',
#     'fullTextURLs': [],
#     'abstracts': [],
#     'tableOfContentURLs': [],
#     'identifier': [{'value': '990038910750603338',
#       'idType': 'almaBib',
#       'prefix': None,
#       'additionalInfos': []},
#      {'value': 'AC08958802',
#       'idType': 'primaryBib',
#       'prefix': None,
#       'additionalInfos': []},
#      {'value': '9783777453514',
#       'idType': 'isbn',
#       'prefix': None,
#       'additionalInfos': ['Museumsausgabe']},
#      {'value': '9783777449715',
#       'idType': 'isbn',
#       'prefix': None,
#       'additionalInfos': ['Buchhandelsausgabe']},
#      {'value': '9783777449814',
#       'idType': 'other',
#       'prefix': None,
#       'additionalInfos': []},
#      {'value': 'AC08958802',
#       'idType': 'systemId',
#       'prefix': '(AT-OBV)',
#       'additionalInfos': []},
#      {'value': 'AC08958802',
#       'idType': 'systemId',
#       'prefix': None,
#       'additionalInfos': []},
#      {'value': '008974256ACC01',
#       'idType': 'systemId',
#       'prefix': '(Aleph)',
#       'additionalInfos': []},
#      {'value': 'OBVAC08958802',
#       'idType': 'systemId',
#       'prefix': '(DE-599)',
#       'additionalInfos': []},
#      {'value': '990089742560203331',
#       'idType': 'systemId',
#       'prefix': '(EXLNZ-43ACC_NETWORK)',
#       'additionalInfos': []}],
#     'holdingInfos': [{'libraryCode': 'ZNEU',
#       'libraryLabel': 'Central Service Facility at Heldenplatz (NEU)',
#       'locationCode': 'MAG',
#       'locationLabel': 'Main Stacks at Heldenplatz (MAG)',
#       'callNumber': '1974955-D',
#       'itemInfos': {'numOfItems': 1, 'availability': 'available'}},
#      {'libraryCode': 'ZALT',
#       'libraryLabel': 'Department of Manuscripts and Rare Books (ALT)',
#       'locationCode': 'AUG',
#       'locationLabel': 'Augustinian Reading Room at Josefsplatz (ALT-AUG)',
#       'callNumber': '1977601-D',
#       'itemInfos': {'numOfItems': 1, 'availability': 'available'}}]},
#    'additionalRecsSRU': {'records': [{'searchType': 'author',
#       'name': '',
#       'maxRecs': 10,
#       'additionalRecs': []}]},
#    'gndInfoLobid': None,
#    'wikidataData': None,
#    'bookCover': None,
#    'bookDescription': None,
#    'iName': 'oenb',
#    'identifierType': 'ac'}}}

# %% [markdown]
# #### Full Deep Extraction (SRU + Lobid + Wikidata Lookup)

# %%
import requests

url = "http://127.0.0.1:8000/enrich"

payload = {
    "iType": "bib",
    "institution": {
        "iName": "oenb",
        "identifier": "+Z168276302",
        "identifierType": "barcode",
        "fetchMarc21MD": True,
        "fetchLobidGND": True,
        "fetchWikidata": True
    }
}

res = requests.post(url, json=payload)
res.raise_for_status()

res.json()
# Out:
# {'response': {'iType': 'bib',
#   'result': {'identifier': '+Z168276302',
#    'basicMarc21MD': {'title': {'titleMain': 'Grundlegung zur Metaphysik der Sitten',
#      'titleRemainder': None,
#      'titlePartNumber': [],
#      'titlePartName': []},
#     'mainEntry': {'name': 'Kant, Immanuel',
#      'nameType': 'personal',
#      'relator': ['aut'],
#      'gndIdentifier': '118559796'},
#     'addedEntries': [],
#     'languageCodes': [],
#     'languageCodesOriginal': [],
#     'publicationCountryCodes': [],
#     'edition': None,
#     'physicalDescriptions': [],
#     'publicationNotices': [{'pnType': 'other',
#       'dating': None,
#       'places': ['Riga'],
#       'names': ['Hartknoch'],
#       'dates': ['1785']}],
#     'genreForms': [],
#     'subjectHeadings': ['Ethik', 'Metaphysik'],
#     'classifications': [],
#     'bibMaterialType': 'Book (BK)',
#     'bibResourceType': 'Book - Physical',
#     'fullTextURLs': ['http://data.onb.ac.at/ABO/%2BZ168276302',
#      'http://data.onb.ac.at/ABO/%2BZ201309403'],
#     'abstracts': [],
#     'tableOfContentURLs': [],
#     'identifier': [{'value': '990031646410603338',
#       'idType': 'almaBib',
#       'prefix': None,
#       'additionalInfos': []},
#      {'value': 'AC10004994',
#       'idType': 'primaryBib',
#       'prefix': None,
#       'additionalInfos': []},
#      {'value': 'AC10004994',
#       'idType': 'systemId',
#       'prefix': '(AT-OBV)',
#       'additionalInfos': []},
#      {'value': 'AC10004994',
#       'idType': 'systemId',
#       'prefix': None,
#       'additionalInfos': []},
#      {'value': '010162863ACC01',
#       'idType': 'systemId',
#       'prefix': '(Aleph)',
#       'additionalInfos': []},
#      {'value': 'OBVAC10004994',
#       'idType': 'systemId',
#       'prefix': '(DE-599)',
#       'additionalInfos': []},
#      {'value': '990101628630203331',
#       'idType': 'systemId',
#       'prefix': '(EXLNZ-43ACC_NETWORK)',
#       'additionalInfos': []}],
#     'holdingInfos': [{'libraryCode': 'ZALT',
#       'libraryLabel': 'Department of Manuscripts and Rare Books (ALT)',
#       'locationCode': 'MAG',
#       'locationLabel': 'Stacks at Josefsplatz (ALT-MAG)',
#       'callNumber': '219886-B',
#       'itemInfos': {'numOfItems': 1, 'availability': 'available'}},
#      {'libraryCode': 'ZALT',
#       'libraryLabel': 'Department of Manuscripts and Rare Books (ALT)',
#       'locationCode': 'PRUNK',
#       'locationLabel': 'State Hall at Josefsplatz (ALT-PRUNK)',
#       'callNumber': '*31.E.27',
#       'itemInfos': {'numOfItems': 1, 'availability': 'available'}}]},
#    'additionalRecsSRU': None,
#    'gndInfoLobid': {'gndId': '118559796',
#     'gndInformation': {'entityTypes': ['Person', 'AuthorityRecord'],
#      'depictionURLs': [],
#      'geographicAreaCodes': [],
#      'sameAs': [],
#      'homepage': [],
#      'gndSubjectCategories': [],
#      'preferredName': 'Albert Einstein',
#      'biographicalOrHistoricalInformation': [],
#      'gndType': 'person'}},
#    'wikidataData': {'wikidataId': 'Q1035',
#     'otherIds': ['118559796'],
#     'wikidataInformation': {'P31': ['Q5'],
#      'P18': ['https://upload.wikimedia.org/wikipedia/commons/d/d3/Albert_Einstein_Head.jpg'],
#      'wikidataType': 'person'}},
#    'bookCover': None,
#    'bookDescription': None,
#    'iName': 'oenb',
#    'identifierType': 'barcode'}}}

# %% [markdown]
# #### Selective Bypass Strategy

# %%
import requests

url = "http://127.0.0.1:8000/enrich"

payload = {
    "iType": "bib",
    "institution": {
        "iName": "oenb",
        "identifier": "AC12345678",
        "identifierType": "ac",
        "gndId": "118516477",
        "fetchMarc21MD": False,
        "fetchLobidGND": True,
        "fetchWikidata": False
    }
}

res = requests.post(url, json=payload)
res.raise_for_status()

res.json()
# Out:
# {'response': {'iType': 'bib',
#   'result': {'identifier': 'AC12345678',
#    'basicMarc21MD': None,
#    'additionalRecsSRU': None,
#    'gndInfoLobid': {'gndId': '118516477',
#     'gndInformation': {'entityTypes': ['Person', 'AuthorityRecord'],
#      'depictionURLs': [],
#      'geographicAreaCodes': [],
#      'sameAs': [],
#      'homepage': [],
#      'gndSubjectCategories': [],
#      'preferredName': 'Albert Einstein',
#      'biographicalOrHistoricalInformation': [],
#      'gndType': 'person'}},
#    'wikidataData': None,
#    'bookCover': None,
#    'bookDescription': None,
#    'iName': 'oenb',
#    'identifierType': 'ac'}}}

# %% [markdown]
# #### Use additionalRecs functionality with mock data

# %%
import requests

url = "http://127.0.0.1:8000/enrich"

# test payload validating the concurrent subsidiary SRU routing
payload = {
    "iType": "bib",
    "institution": {
        "iName": "oenb",
        "identifier": "Z168276302",
        "identifierType": "barcode",
        "fetchMarc21MD": True,
        "fetchLobidGND": True,
        "fetchWikidata": True,
        
        # query paths
        "fetchSimilarByAuthor": True,
        "fetchSimilarBySubject": True,
        "fetchSimilarByClassification": True
    }
}

try:
    print("Sending enrichment request...")
    res = requests.post(url, json=payload)
    res.raise_for_status()
    
    data = res.json()
    print("Success! Response received structure:")
    
    # inspect sub-model key inside the JSON response
    result_node = data["response"]["result"]
    print(f"Identifier: {result_node['identifier']}")
    print(f"Basic MARC21 Found: {result_node['basicMarc21MD'] is not None}")
    print(f"Lobid Data Found: {result_node['gndInfoLobid'] is not None}")
    print(f"Wikidata Data Found: {result_node['wikidataData'] is not None}")
    
    # print newly wired multi-strategy array
    print("\n--- Additional Records SRU Output ---")
    print(result_node["additionalRecsSRU"])

except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")
    if e.response is not None:
        print(f"Server response: {e.response.text}")
# Out:
# Sending enrichment request...
# Success! Response received structure:
# Identifier: Z168276302
# Basic MARC21 Found: True
# Lobid Data Found: True
# Wikidata Data Found: True
#
# --- Additional Records SRU Output ---
# {'records': [{'searchType': 'classification', 'classifications': [], 'maxRecs': 5, 'additionalRecs': []}, {'searchType': 'author', 'name': 'Kant, Immanuel', 'maxRecs': 5, 'additionalRecs': [{'ac': 'AC14036130', 'titleMain': '[Ohne Titel]', 'callNumbers': ['Autogr. 144/82-1'], 'isbns': [], 'issns': []}, {'ac': 'AC10005051', 'titleMain': 'A kedély hatalmáról, miszerint a puszta feltett szándék által uralkodhatni a kóros érzelmeken', 'callNumbers': ['58579-B'], 'isbns': [], 'issns': []}, {'ac': 'AC13902513', 'titleMain': 'Adorno und Kant', 'callNumbers': ['Cod. Ser. n. 44243'], 'isbns': [], 'issns': []}, {'ac': 'AC13904422', 'titleMain': 'Adorno und Kant', 'callNumbers': ['Cod. Ser. n. 44204'], 'isbns': [], 'issns': []}, {'ac': 'AC04210882', 'titleMain': 'Al eterna paco', 'callNumbers': ['702052-B'], 'isbns': [], 'issns': []}]}, {'searchType': 'subjectHeadings', 'subjectHeadings': ['Ethik', 'Metaphysik'], 'maxRecs': 5, 'additionalRecs': []}]}

# %% [markdown]
# ### old tests

# %%
# try a request for v2 -> needs to be post request

import requests

url = "http://127.0.0.1:8000/enrich"

# payload matches nested EnrichmentRequest structure:
# Level 3: iType ("bib")
# Level 2: institution
# Level 1: iName ("oenb") + barcode
payload = {
    "iType": "bib",
    "institution": {
        "iName": "oenb",
        "barcode": "Z168276302"
    }
}

res = requests.post(url, json=payload)
res.raise_for_status()

res.json()
# Out:
# {'iType': 'bib',
#  'result': {'iName': 'oenb',
#   'barcode': 'Z168276302',
#   'metadata': {'title245': 'Grundlegung zur Metaphysik der Sitten',
#    'author100': 'Kant, Immanuel',
#    'gndID': '(DE-588)118559796',
#    'titlesGND': ['Gesammelte Schriften',
#     'Die Religion innerhalb der Grenzen der bloßen Vernunft',
#     'Beobachtungen über das Gefühl des Schönen und Erhabenen',
#     'Metaphysische Anfangsgründe der Naturwissenschaft',
#     'Kritik der Urteilskraft']}}}

# %%
# try a request for v1

import requests

# omit "+" in barcode

# Schopenhauer, Die Welt als Wille und Vorstellung
#barcode = "Z17057080X"
#callNum = "19.V.9"
ac = "AC10298143"

# Kant, GMS
#barcode = "Z168276302"
#callNum = "219886-B"
#ac = "AC10004994"

#url = f"http://127.0.0.1:8000/barcode/{barcode}"
#url = f"http://127.0.0.1:8000/callNumber/{callNum}"
url = f"http://127.0.0.1:8000/acNumber/{ac}"

res = requests.get(url)

res.json()
# Out:
# {'id': 'AC10298143',
#  'idType': 'acNumber',
#  'title245': 'Die Welt als Wille und Vorstellung; 4 Bücher, nebst einem Anh., der die Kritik der Kantischen Philosophie enthält.',
#  'author100': 'Schopenhauer, Arthur',
#  'gndID': '(DE-588)118610465',
#  'titlesGND': ['Über das Sehen und die Farben',
#   '"Kan Menneskets frie Villie bevises af dets Selvbevidsthed?"',
#   'Die beiden Grundprobleme der Ethik, behandelt in zwei akadem. Preisschriften',
#   'Über die vierfache Wurzel des Satzes vom hinreichenden Grunde',
#   'Über die Lebensalter',
#   'Aphorismen zur Lebensweisheit',
#   'Über die Weiber',
#   'Die Welt als Wille und Vorstellung']}

# %%
import requests

# gnd id
gndID = "118610465"

url = f"https://lobid.org/gnd/{gndID}.json"

res = requests.get(url)

resultDict = res.json()

resultDict["publication"]
# Out:
# ['Über das Sehen und die Farben',
#  '"Kan Menneskets frie Villie bevises af dets Selvbevidsthed?"',
#  'Die beiden Grundprobleme der Ethik, behandelt in zwei akadem. Preisschriften',
#  'Über die vierfache Wurzel des Satzes vom hinreichenden Grunde',
#  'Über die Lebensalter',
#  'Aphorismen zur Lebensweisheit',
#  'Über die Weiber',
#  'Die Welt als Wille und Vorstellung']
