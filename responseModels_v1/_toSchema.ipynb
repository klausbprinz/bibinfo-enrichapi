# %%
import json
from model_response import oenbResponse

# Generate the schema as a dictionary
schema_dict = oenbResponse.model_json_schema()

# Save to a file for easy reading
with open("response_schema.json", "w", encoding="utf-8") as f:
    json.dump(schema_dict, f, indent=2)

print("Schema generated successfully!")
# Out:
# Schema generated successfully!
